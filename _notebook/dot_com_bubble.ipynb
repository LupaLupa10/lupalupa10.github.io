# %%
pip install pandas bs4 requests

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def fetch_dot_plot_html(date_str):
    # date_str format: YYYYMMDD, e.g. "20250618"
    url = f"https://www.federalreserve.gov/monetarypolicy/fomcprojtabl{date_str}.htm"
    resp = requests.get(url)
    resp.raise_for_status()
    return resp.text

def parse_dot_plot(html):
    soup = BeautifulSoup(html, "html.parser")
    # The projection table is inside <table> tags, you'll need to find the correct one.
    # This example assumes it's the first or a known index:
    tables = pd.read_html(html)

# %%
print(df.head())
